# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import random as random

# %%
uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)

# %%
df1 = pd.read_csv("sample_files.csv")
headers = list(pd.read_csv("cols_varscan.txt",sep = "\t").columns)
df_pandas = pd.read_csv("veryexonic.txt",sep = "\t",names = headers)

# %%
# Out:
# Start                                                            874821
# End                                                              874821
# Ref                                                                   T
# Alt                                                                   C
# Func.refGene                                                     exonic
# Gene.refGene                                                     SAMD11
# GeneDetail.refGene                                                    .
# ExonicFunc.refGene                                       synonymous SNV
# AAChange.refGene                 SAMD11:NM_152486:exon7:c.T687C:p.P229P
# Func.ensGene                                                     exonic
# Gene.ensGene                                            ENSG00000187634
# GeneDetail.ensGene                                                    .
# ExonicFunc.ensGene                                       synonymous SNV
# ...

# %%
del df1["Unnamed: 0"]

# %%
df2 = df1[(df1['AF'] != '.') & (df1['AF_afr'] == '.')]

# %%
df2.iloc[0][1:50]
# Out:
# Start                                                           1355583
# End                                                             1355583
# Ref                                                                   C
# Alt                                                                   A
# Func.refGene                                                     exonic
# Gene.refGene                                                    ANKRD65
# GeneDetail.refGene                                                    .
# ExonicFunc.refGene                                    nonsynonymous SNV
# AAChange.refGene             ANKRD65:NM_001145210:exon3:c.G599T:p.G200V
# Func.ensGene                                                     exonic
# Gene.ensGene                                            ENSG00000235098
# GeneDetail.ensGene                                                    .
# ExonicFunc.ensGene                                    nonsynonymous SNV
# ...

# %%
df1[df1["Gene.refGene"] == 'LINGO4']
# Out:
#         Chr      Start        End Ref        Alt Func.refGene Gene.refGene  \
# 24420  chr1  151773549  151773549   G          A       exonic       LINGO4
# 24421  chr1  151773557  151773557   -  GAGGAAGCC       exonic       LINGO4
# 24422  chr1  151773600  151773600   C          A       exonic       LINGO4
# 24423  chr1  151773603  151773603   A          -       exonic       LINGO4
# 24424  chr1  151773630  151773630   G          A       exonic       LINGO4
# 24425  chr1  151773711  151773711   A          G       exonic       LINGO4
# 24426  chr1  151773713  151773713   C          T       exonic       LINGO4
# 24427  chr1  151773851  151773851   T          A       exonic       LINGO4
# 24428  chr1  151774033  151774033   G          -       exonic       LINGO4
# 24429  chr1  151774088  151774088   G          A       exonic       LINGO4
# 24430  chr1  151774197  151774197   G          A       exonic       LINGO4
# ...

# %%
AF_list = ['AF','AF_afr',
 'AF_sas',
 'AF_amr',
 'AF_eas',
 'AF_nfe',
 'AF_fin',
 'AF_asj',
 'AF_oth']

for elem in AF_list:
    df_pandas = df_pandas[(df_pandas[elem] != '.')]

# %%
sns.distplot(df_pandas_proc['AF'].astype(float),bins = 5,kde=True)
# df_pandas[38]

# %%
# Print out the various ethnicities here.
AF_list = ['AF','AF_afr',
 'AF_sas',
 'AF_amr',
 'AF_eas',
 'AF_nfe',
 'AF_fin',
 'AF_asj',
 'AF_oth']

for elem in AF_list:
    print(elem)
    sns.distplot(df_pandas[elem].astype(float),bins = 5,kde=True)
# Out:
# AF
# AF_afr
# AF_sas
# AF_amr
# AF_eas
# AF_nfe
# AF_fin
# AF_asj
# AF_oth

# %%
len(df_pandas['Chr'])
# Out:
# 367195

# %%
# Use heatmap.
samples_list = list(header for header in list(df_pandas.columns) if 'Sample' in header)
n1 = np.ones((len(samples_list)))
# Out:
# ['Sample_100A',
#  'Sample_101A',
#  'Sample_102A_LB189_FG',
#  'Sample_103A_LB190_DH',
#  'Sample_104A',
#  'Sample_105A',
#  'Sample_106A',
#  'Sample_107A',
#  'Sample_109A',
#  'Sample_10A',
#  'Sample_110C',
#  'Sample_110C_LB373_AT_212A',
#  'Sample_111A',
#  'Sample_112A',
#  'Sample_113A',
#  'Sample_114A',
#  'Sample_115A',
#  'Sample_116A',
#  'Sample_117A_LB217_RR',
#  'Sample_11847',
#  'Sample_11848',
#  'Sample_11849',
#  'Sample_11850',
#  'Sample_11851',
#  'Sample_11852',
#  'Sample_11853',
#  'Sample_11854',
#  'Sample_11855',
#  'Sample_11856',
#  'Sample_11857',
#  'Sample_11858',
#  'Sample_11860',
#  'Sample_11861',
#  'Sample_11862',
#  'Sample_11865',
#  'Sample_11866',
#  'Sample_11868',
#  'Sample_11869',
#  'Sample_11870',
#  'Sample_11871',
#  'Sample_11875',
#  'Sample_11876',
#  'Sample_11877',
#  'Sample_11878',
#  'Sample_11879',
#  'Sample_11880',
#  'Sample_11882',
#  'Sample_11883',
#  'Sample_11884',
#  'Sample_11885',
#  'Sample_11886',
# ...

# %%
df_np = df_pandas.to_numpy()
df_np[np.where(df_pandas == '.')] = 0
# Out:
# /Users/kennethpienta/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
samples = df_np[:,headers.index("Sample_100A"):]

# %%
samples[np.where(samples != 0)] = 1

# %%
l = list(random.randint(0,samples.shape[0]) for i in range(10))
samples = samples.astype('int')

# %%
sns.heatmap(samples)
